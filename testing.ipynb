# %%
# %pip install numpy 
# %pip install matplotlib
from genre_predictor.Spotify_project import Genre_Predictor
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#      ---------------------------------------- 7.5/7.5 MB 53.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.1/2.1 MB 44.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 55.4/55.4 kB 3.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 98.3/98.3 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 2.5/2.5 MB 53.3 MB/s eta 0:00:00
# ...
#      ------------------------------------- 429.4/429.4 kB 27.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#  Volume in drive C is Local Disk
#  Volume Serial Number is B627-5AF4
#
#  Directory of c:\Users\HenryWhite\OneDrive - Sidrat Research\Desktop\AI Training Project - Henry\AI Training Project - Henry\Genre_Predictor
#
# 2023-08-09  02:12 PM    <DIR>          .
# 2023-08-08  04:13 PM    <DIR>          ..
# 2023-08-02  10:31 AM             3,238 .gitignore
# ...
